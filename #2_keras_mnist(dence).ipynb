# %% [markdown]
# ## Dependencies

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ## Load

# %%
(X_train, y_train), (X_valid, y_valid) = mnist.load_data()

# %% [markdown]
# ## Preprocess

# %%
X_train = X_train.reshape(60000, 784).astype('float32')
X_valid = X_valid.reshape(10000, 784).astype('float32')

# %%
X_train /= 255
X_valid /= 255

# %%
n_classes = 10
y_train = keras.utils.np_utils.to_categorical(y_train, n_classes)
y_valid = keras.utils.np_utils.to_categorical(y_valid, n_classes)

# %% [markdown]
# ## Design architecture

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Configure model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.1),
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## Train

# %%
model.fit(X_train, y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 3s 4ms/step - loss: 0.4865 - accuracy: 0.8598 - val_loss: 0.2645 - val_accuracy: 0.9197
# Epoch 2/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2281 - accuracy: 0.9339 - val_loss: 0.1781 - val_accuracy: 0.9497
# Epoch 3/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1723 - accuracy: 0.9502 - val_loss: 0.1537 - val_accuracy: 0.9544
# Epoch 4/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1393 - accuracy: 0.9595 - val_loss: 0.1339 - val_accuracy: 0.9601
# Epoch 5/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1198 - accuracy: 0.9651 - val_loss: 0.1235 - val_accuracy: 0.9620
# Epoch 6/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1039 - accuracy: 0.9692 - val_loss: 0.1097 - val_accuracy: 0.9663
# Epoch 7/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0926 - accuracy: 0.9726 - val_loss: 0.1063 - val_accuracy: 0.9686
# Epoch 8/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0830 - accuracy: 0.9748 - val_loss: 0.1002 - val_accuracy: 0.9691
# Epoch 9/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0745 - accuracy: 0.9782 - val_loss: 0.0933 - val_accuracy: 0.9714
# Epoch 10/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0687 - accuracy: 0.9791 - val_loss: 0.0950 - val_accuracy: 0.9706

# %% [markdown]
# ## Evaluate

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0950 - accuracy: 0.9706
# [0.0949724093079567, 0.9706000089645386]
